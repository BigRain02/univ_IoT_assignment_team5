# %%
# !pip install ultralytics -q
from ultralytics import YOLO
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.3/760.3 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 54.0 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/yolov8-out
# !ls
# Out:
# /content/drive/MyDrive/yolov8-out
# test.txt

# %%
model = YOLO("yolov8l.pt")
model.train(data = '/content/drive/MyDrive/YOLODataset/dataset.yaml', epochs=5)
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 203MB/s]
# Ultralytics YOLOv8.2.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
